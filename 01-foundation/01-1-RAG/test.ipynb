# %%
import os

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
openai_client = OpenAI()

# %%
# Confirm local secret configuration without echoing the value.
"MY_SECRET_KEY" in os.environ
