# %%
import os

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

openai_client = OpenAI()

# %%
# Out:
# True

# %%
secret_key = os.getenv("MY_SECRET_KEY")
"MY_SECRET_KEY is configured" if secret_key else "MY_SECRET_KEY is not set"
# Out:
# 'LOL'
